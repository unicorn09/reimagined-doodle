# %%
import requests
import csv
from bs4 import BeautifulSoup


filename="north_food.csv"
col=['Food Item','Type','Link','Energy','Protein','Carbohydrate','Fat','Health Meter','Indgredients'] 

#Refer to this for food 
l=[]
page = requests.get("https://www.balancenutrition.in/recipes/cuisines/north-indian")
soup = BeautifulSoup(page.content, 'html.parser')
for div in soup.findAll('div', attrs={'class':'row cuisine'}):
    try:

      alpha=div.find('a')
      while(alpha.findNext('a')):
        s=str(alpha['href'])
        if s.find("https://www.balancenutrition.in/recipes/")==-1:
          break
        alpha=alpha.findNext('a')
        l.append(alpha['href'])
        
    except:
      print()

energy=None
protein=None
carbo=None
fat=None
meter=None
with open(filename,'a',newline='') as csvfile:
        writer=csv.writer(csvfile,delimiter=',', dialect='excel')
        writer.writerow(col)

for j in l:
 
  result = requests.get(j)
  src = result.content
  soup = BeautifulSoup(src, 'html.parser')
  fitem=soup.find('h1',{"class":"recipe-title","style":"text-transform:none !important;"}).text
  print(fitem)
  t1=soup.find('div',class_="recipe-heading")
  t2=t1.find('div')
  t3=str(t2.find('img'))
  k=(t3.find("https://www.balancenutrition.in/images/recipes/"))+len("https://www.balancenutrition.in/images/recipes/")
  p=t3.find(".png")
  typ=(t3[k:p])
  tag1=soup.find('div',class_="col-md-3 energy col-sm-6 col-xs-6 recipe-shared-btm")
  if(tag1!=None):
    energy=tag1.find('p')
  if(energy!=None):
    energy=energy.text
  tag2=soup.find('div',class_="col-md-3 protien col-sm-6 col-xs-6 recipe-shared-btm")
  if(tag2!=None):
    protein=tag2.find('p')
  if(protein!=None):
    protein=protein.text
  tag3=soup.find('div',class_="col-md-3 carbs col-sm-6 col-xs-6 recipe-shared-btm")
  if(tag3!=None):
    carbo=tag3.find('p')
  if(carbo!=None):
    carbo=carbo.text
  tag4=soup.find('div',class_="col-md-3 fats col-sm-6 col-xs-6 recipe-shared-btm")
  if(tag4!=None):
    fat=tag4.find('p')
  if(fat!=None):
    fat=fat.text
  tag5=soup.find('div',class_="health-meter")

  meter=tag5.find('p').text

  tag6=soup.find('div',class_='ingredient-list')
  if(tag6!=None):
    itemp1=tag6.find('ul')
  if(itemp1!=None):
    ind=itemp1.find_all('li')
  print(ind)
  indgredients=[]

  for i in ind:
    value=i.find('span',{"style":"line-height: 1.42857;"})
    if(value!=None):
      value=value.text
      indgredients.append(value)
  if(len(indgredients)==0):
    for k in ind:
      indgredients.append(k.text)
    
  li=[]
  li.append(fitem)
  li.append(typ)
  li.append(j)
  li.append(energy)
  li.append(protein)
  li.append(carbo)
  li.append(fat)
  li.append(meter)
  
  li.append(indgredients)
  print(li)
  with open(filename,'a',newline='') as csvfile:
        writer=csv.writer(csvfile,delimiter=',', dialect='excel')
        writer.writerow(li)
# Out:
# apple-suji-kheer
# [<li><span style="line-height: 1.42857;">Suji - 1 tbsp</span><br/></li>, <li><span style="line-height: 1.42857;">Apple - ½ no </span><br/></li>, <li><span style="line-height: 1.42857;">Milk - ½ cup</span><br/></li>, <li><span style="line-height: 1.42857;">Water as required</span><br/></li>]
# ['apple-suji-kheer', 'veg', 'https://www.balancenutrition.in/recipes/recipe-details/apple-suji-kheer', 'Energy (kcal)- 125', 'Protein (g) - 4', 'Carbohydrate (g)- 20', 'Fat (g) - 3', " Apple Suji kheer is an excellent combination of carbohydrates and protein as well as complimenting them with minerals and vitamins which is necessary for baby's growth.  It is quick to make and at the same time is healthy for the baby.", ['Suji - 1 tbsp', 'Apple - ½ no\xa0', 'Milk - ½ cup', 'Water as required']]
# baag-hare-gajar
# ...

# %%
import requests
import csv
from bs4 import BeautifulSoup


filename="south_food.csv"
col=['Food Item','Type','Link','Energy','Protein','Carbohydrate','Fat','Health Meter','Indgredients'] 

#Refer to this for food 
l=[]
page = requests.get("https://www.balancenutrition.in/recipes/cuisines/south-indian")
soup = BeautifulSoup(page.content, 'html.parser')
for div in soup.findAll('div', attrs={'class':'row cuisine'}):
    try:

      alpha=div.find('a')
      while(alpha.findNext('a')):
        s=str(alpha['href'])
        if s.find("https://www.balancenutrition.in/recipes/")==-1:
          break
        alpha=alpha.findNext('a')
        l.append(alpha['href'])
        
    except:
      print()

energy=None
protein=None
carbo=None
fat=None
meter=None
with open(filename,'a',newline='') as csvfile:
        writer=csv.writer(csvfile,delimiter=',', dialect='excel')
        writer.writerow(col)

for j in l:
 
  result = requests.get(j)
  src = result.content
  soup = BeautifulSoup(src, 'html.parser')
  fitem=soup.find('h1',{"class":"recipe-title","style":"text-transform:none !important;"}).text
  print(fitem)
  t1=soup.find('div',class_="recipe-heading")
  t2=t1.find('div')
  t3=str(t2.find('img'))
  k=(t3.find("https://www.balancenutrition.in/images/recipes/"))+len("https://www.balancenutrition.in/images/recipes/")
  p=t3.find(".png")
  typ=(t3[k:p])
  tag1=soup.find('div',class_="col-md-3 energy col-sm-6 col-xs-6 recipe-shared-btm")
  if(tag1!=None):
    energy=tag1.find('p')
  try:
    if(energy!=None):
      energy=energy.text
  
    tag2=soup.find('div',class_="col-md-3 protien col-sm-6 col-xs-6 recipe-shared-btm")
    if(tag2!=None):
      protein=tag2.find('p')
    if(protein!=None):
      protein=protein.text
    tag3=soup.find('div',class_="col-md-3 carbs col-sm-6 col-xs-6 recipe-shared-btm")
    if(tag3!=None):
      carbo=tag3.find('p')
    if(carbo!=None):
      carbo=carbo.text
    tag4=soup.find('div',class_="col-md-3 fats col-sm-6 col-xs-6 recipe-shared-btm")
    if(tag4!=None):
      fat=tag4.find('p')
    if(fat!=None):
      fat=fat.text
    tag5=soup.find('div',class_="health-meter")

    meter=tag5.find('p').text

    tag6=soup.find('div',class_='ingredient-list')
    if(tag6!=None):
      itemp1=tag6.find('ul')
    if(itemp1!=None):
      ind=itemp1.find_all('li')
    print(ind)
    indgredients=[]
  except:
     print()
  for i in ind:
    value=i.find('span',{"style":"line-height: 1.42857;"})
    if(value!=None):
      value=value.text
      indgredients.append(value)
  if(len(indgredients)==0):
    for k in ind:
      indgredients.append(k.text)
    
  li=[]
  li.append(fitem)
  li.append(typ)
  li.append(j)
  li.append(energy)
  li.append(protein)
  li.append(carbo)
  li.append(fat)
  li.append(meter)
  
  li.append(indgredients)
  print(li)
  with open(filename,'a',newline='') as csvfile:
        writer=csv.writer(csvfile,delimiter=',', dialect='excel')
        writer.writerow(li)
# Out:
# Alleppey Style Soya Vegetable Curry
# [<li><span style="line-height: 1.42857;">Potatoes peeled - 20 g</span><br/></li>, <li><span style="line-height: 1.42857;">Runner beans (chavli beans) -15 g</span><br/></li>, <li><span style="line-height: 1.42857;">Carrot-1 medium</span><br/></li>, <li><span style="line-height: 1.42857;">Tomato-1 medium</span><br/></li>, <li><span style="line-height: 1.42857;">Curry leaves-5 to 7</span><br/></li>, <li><span style="line-height: 1.42857;">Soya nuggets soaked- 30 g</span><br/></li>, <li><span style="line-height: 1.42857;">Dried red chillies broken-2-3</span><br/></li>, <li><span style="line-height: 1.42857;">Turmeric powder-1/4 tsp</span><br/></li>, <li><span style="line-height: 1.42857;">Mustard seeds-1/2 tsp</span><br/></li>, <li><span style="line-height: 1.42857;">Salt-to taste</span><br/></li>, <li><span style="line-height: 1.42857;">Water- 2 tbsp</span></li>]
# ...

# %%
import requests
import csv
from bs4 import BeautifulSoup


filename="east_food.csv"
col=['Food Item','Type','Link','Energy','Protein','Carbohydrate','Fat','Health Meter','Indgredients'] 

#Refer to this for food 
l=[]
page = requests.get("https://www.balancenutrition.in/recipes/cuisines/assamese")
soup = BeautifulSoup(page.content, 'html.parser')
for div in soup.findAll('div', attrs={'class':'row cuisine'}):
    try:

      alpha=div.find('a')
      while(alpha.findNext('a')):
        s=str(alpha['href'])
        if s.find("https://www.balancenutrition.in/recipes/")==-1:
          break
        alpha=alpha.findNext('a')
        l.append(alpha['href'])
        
    except:
      print()

energy=None
protein=None
carbo=None
fat=None
meter=None
with open(filename,'a',newline='') as csvfile:
        writer=csv.writer(csvfile,delimiter=',', dialect='excel')
        writer.writerow(col)

for j in l:
 
  result = requests.get(j)
  src = result.content
  soup = BeautifulSoup(src, 'html.parser')
  try:
    f=len("https://www.balancenutrition.in/recipes/recipe-details/")
    fitem=j[f:]
    print(fitem)
    t1=soup.find('div',class_="recipe-heading")
    t2=t1.find('div')
    t3=str(t2.find('img'))
    k=(t3.find("https://www.balancenutrition.in/images/recipes/"))+len("https://www.balancenutrition.in/images/recipes/")
    p=t3.find(".png")
    typ=(t3[k:p])
    tag1=soup.find('div',class_="col-md-3 energy col-sm-6 col-xs-6 recipe-shared-btm")
    if(tag1!=None):
      energy=tag1.find('p')
 
    if(energy!=None):
      energy=energy.text
  
    tag2=soup.find('div',class_="col-md-3 protien col-sm-6 col-xs-6 recipe-shared-btm")
    if(tag2!=None):
      protein=tag2.find('p')
    if(protein!=None):
      protein=protein.text
    tag3=soup.find('div',class_="col-md-3 carbs col-sm-6 col-xs-6 recipe-shared-btm")
    if(tag3!=None):
      carbo=tag3.find('p')
    if(carbo!=None):
      carbo=carbo.text
    tag4=soup.find('div',class_="col-md-3 fats col-sm-6 col-xs-6 recipe-shared-btm")
    if(tag4!=None):
      fat=tag4.find('p')
    if(fat!=None):
      fat=fat.text
    tag5=soup.find('div',class_="health-meter")

    meter=tag5.find('p').text

    tag6=soup.find('div',class_='ingredient-list')
    if(tag6!=None):
      itemp1=tag6.find('ul')
    if(itemp1!=None):
      ind=itemp1.find_all('li')
    print(ind)
    indgredients=[]
  except:
     print()
  for i in ind:
    value=i.find('span',{"style":"line-height: 1.42857;"})
    if(value!=None):
      value=value.text
      indgredients.append(value)
  if(len(indgredients)==0):
    for k in ind:
      indgredients.append(k.text)
    
  li=[]
  li.append(fitem)
  li.append(typ)
  li.append(j)
  li.append(energy)
  li.append(protein)
  li.append(carbo)
  li.append(fat)
  li.append(meter)
  
  li.append(indgredients)
  print(li)
  with open(filename,'a',newline='') as csvfile:
        writer=csv.writer(csvfile,delimiter=',', dialect='excel')
        writer.writerow(li)
# Out:
# assamese-labra
# [<li>Pumpkin, cauliflower, aubergine, carrot (mixed vegetables) - 50 g<br/></li>, <li>Sweet potato - 1 medium<br/></li>, <li>Onion chopped - 1 small<br/></li>, <li>Whole dried red chilli- 1<br/></li>, <li>Oil- 1/2 tsp<br/></li>, <li>Ginger grated- ½ tsp (optional)<br/></li>, <li>Green chilli-1</li>, <li>Turmeric - 1/4 tsp<br/></li>, <li>Water 1/4 cup<br/></li>, <li>Asafoetida- 1/4 tsp<br/></li>, <li>Salt - as per taste<br/></li>, <li>Green coriander - for garnishing<br/></li>, <li>Bay leaf - 1 <br/></li>, <li>Cumin seeds- ¼ tsp<br/></li>]
# ...

# %%
import requests
import csv
from bs4 import BeautifulSoup


filename="east_food.csv"
col=['Food Item','Type','Link','Energy','Protein','Carbohydrate','Fat','Health Meter','Indgredients'] 

#Refer to this for food 
l=[]
page = requests.get("https://www.balancenutrition.in/recipes/cuisines/bengali")
soup = BeautifulSoup(page.content, 'html.parser')
for div in soup.findAll('div', attrs={'class':'row cuisine'}):
    try:

      alpha=div.find('a')
      while(alpha.findNext('a')):
        s=str(alpha['href'])
        if s.find("https://www.balancenutrition.in/recipes/")==-1:
          break
        alpha=alpha.findNext('a')
        l.append(alpha['href'])
        
    except:
      print()

energy=None
protein=None
carbo=None
fat=None
meter=None


for j in l:
 
  result = requests.get(j)
  src = result.content
  soup = BeautifulSoup(src, 'html.parser')
  try:
    f=len("https://www.balancenutrition.in/recipes/recipe-details/")
    fitem=j[f:]
    print(fitem)
    t1=soup.find('div',class_="recipe-heading")
    t2=t1.find('div')
    t3=str(t2.find('img'))
    k=(t3.find("https://www.balancenutrition.in/images/recipes/"))+len("https://www.balancenutrition.in/images/recipes/")
    p=t3.find(".png")
    typ=(t3[k:p])
    tag1=soup.find('div',class_="col-md-3 energy col-sm-6 col-xs-6 recipe-shared-btm")
    if(tag1!=None):
      energy=tag1.find('p')
 
    if(energy!=None):
      energy=energy.text
  
    tag2=soup.find('div',class_="col-md-3 protien col-sm-6 col-xs-6 recipe-shared-btm")
    if(tag2!=None):
      protein=tag2.find('p')
    if(protein!=None):
      protein=protein.text
    tag3=soup.find('div',class_="col-md-3 carbs col-sm-6 col-xs-6 recipe-shared-btm")
    if(tag3!=None):
      carbo=tag3.find('p')
    if(carbo!=None):
      carbo=carbo.text
    tag4=soup.find('div',class_="col-md-3 fats col-sm-6 col-xs-6 recipe-shared-btm")
    if(tag4!=None):
      fat=tag4.find('p')
    if(fat!=None):
      fat=fat.text
    tag5=soup.find('div',class_="health-meter")

    meter=tag5.find('p').text

    tag6=soup.find('div',class_='ingredient-list')
    if(tag6!=None):
      itemp1=tag6.find('ul')
    if(itemp1!=None):
      ind=itemp1.find_all('li')
    print(ind)
    indgredients=[]
  except:
     print()
  for i in ind:
    value=i.find('span',{"style":"line-height: 1.42857;"})
    if(value!=None):
      value=value.text
      indgredients.append(value)
  if(len(indgredients)==0):
    for k in ind:
      indgredients.append(k.text)
    
  li=[]
  li.append(fitem)
  li.append(typ)
  li.append(j)
  li.append(energy)
  li.append(protein)
  li.append(carbo)
  li.append(fat)
  li.append(meter)
  
  li.append(indgredients)
  print(li)
  with open(filename,'a',newline='') as csvfile:
        writer=csv.writer(csvfile,delimiter=',', dialect='excel')
        writer.writerow(li)
# Out:
# bengali-murghir-jhol
# [<li>Chicken - 50 g</li>, <li>Sweet potato - 10 g</li>, <li>Onion - 20 g</li>, <li>Ginger garlic paste - 1 tsp</li>, <li>Plain yogurt - 1 tbsp</li>, <li>Tomato pulp - 1 tbsp</li>, <li>Turmeric powder - a pinch </li>, <li>Red chilli powder - a pinch </li>, <li>Coriander powder - a pinch </li>, <li>Mustard seeds - 1 tsp</li>, <li>Oil - ½ tsp</li>, <li>Cloves - 1 no. </li>, <li>Cinnamon - small piece </li>, <li>Dry red chilli - ½  piece </li>, <li>Coriander leaves - 1 tsp</li>, <li>Salt as per the taste</li>]
# ...

# %%
import requests
import csv
from bs4 import BeautifulSoup


filename="west_food.csv"
col=['Food Item','Type','Link','Energy','Protein','Carbohydrate','Fat','Health Meter','Indgredients'] 

#Refer to this for food 
l=[]
page = requests.get("https://www.balancenutrition.in/recipes/cuisines/gujarati")
soup = BeautifulSoup(page.content, 'html.parser')
for div in soup.findAll('div', attrs={'class':'row cuisine'}):
    try:

      alpha=div.find('a')
      while(alpha.findNext('a')):
        s=str(alpha['href'])
        if s.find("https://www.balancenutrition.in/recipes/")==-1:
          break
        alpha=alpha.findNext('a')
        l.append(alpha['href'])
        
    except:
      print()

energy=None
protein=None
carbo=None
fat=None
meter=None
with open(filename,'a',newline='') as csvfile:
        writer=csv.writer(csvfile,delimiter=',', dialect='excel')
        writer.writerow(col)

for j in l:
 
  result = requests.get(j)
  src = result.content
  soup = BeautifulSoup(src, 'html.parser')
  try:
    f=len("https://www.balancenutrition.in/recipes/recipe-details/")
    fitem=j[f:]
    print(fitem)
    t1=soup.find('div',class_="recipe-heading")
    t2=t1.find('div')
    t3=str(t2.find('img'))
    k=(t3.find("https://www.balancenutrition.in/images/recipes/"))+len("https://www.balancenutrition.in/images/recipes/")
    p=t3.find(".png")
    typ=(t3[k:p])
    tag1=soup.find('div',class_="col-md-3 energy col-sm-6 col-xs-6 recipe-shared-btm")
    if(tag1!=None):
      energy=tag1.find('p')
 
    if(energy!=None):
      energy=energy.text
  
    tag2=soup.find('div',class_="col-md-3 protien col-sm-6 col-xs-6 recipe-shared-btm")
    if(tag2!=None):
      protein=tag2.find('p')
    if(protein!=None):
      protein=protein.text
    tag3=soup.find('div',class_="col-md-3 carbs col-sm-6 col-xs-6 recipe-shared-btm")
    if(tag3!=None):
      carbo=tag3.find('p')
    if(carbo!=None):
      carbo=carbo.text
    tag4=soup.find('div',class_="col-md-3 fats col-sm-6 col-xs-6 recipe-shared-btm")
    if(tag4!=None):
      fat=tag4.find('p')
    if(fat!=None):
      fat=fat.text
    tag5=soup.find('div',class_="health-meter")

    meter=tag5.find('p').text

    tag6=soup.find('div',class_='ingredient-list')
    if(tag6!=None):
      itemp1=tag6.find('ul')
    if(itemp1!=None):
      ind=itemp1.find_all('li')
    print(ind)
    indgredients=[]
  except:
     print()
  for i in ind:
    value=i.find('span',{"style":"line-height: 1.42857;"})
    if(value!=None):
      value=value.text
      indgredients.append(value)
  if(len(indgredients)==0):
    for k in ind:
      indgredients.append(k.text)
    
  li=[]
  li.append(fitem)
  li.append(typ)
  li.append(j)
  li.append(energy)
  li.append(protein)
  li.append(carbo)
  li.append(fat)
  li.append(meter)
  
  li.append(indgredients)
  print(li)
  with open(filename,'a',newline='') as csvfile:
        writer=csv.writer(csvfile,delimiter=',', dialect='excel')
        writer.writerow(li)
# Out:
# bajra-burfi
# [<li><span style="line-height: 1.42857;">Bajra -20 g</span><br/></li>, <li><span style="line-height: 1.42857;">Milk -75 ml </span><br/></li>, <li><span style="line-height: 1.42857;">Sugar - 1 tsp</span><br/></li>, <li><span style="line-height: 1.42857;">Nutmeg powder -  ¼ tsp </span><br/></li>, <li><span style="line-height: 1.42857;">Green cardamom powder - ½ tsp </span><br/></li>, <li><span style="line-height: 1.42857;">Sunflower seeds - for garnishing </span><br/></li>, <li><span style="line-height: 1.42857;">Rose petals -  for garnishing</span><br/></li>]
# ...

# %%
import requests
import csv
from bs4 import BeautifulSoup


filename="west_food.csv"
col=['Food Item','Type','Link','Energy','Protein','Carbohydrate','Fat','Health Meter','Indgredients'] 

#Refer to this for food 
l=[]
page = requests.get("https://www.balancenutrition.in/recipes/cuisines/maharashtrian")
soup = BeautifulSoup(page.content, 'html.parser')
for div in soup.findAll('div', attrs={'class':'row cuisine'}):
    try:

      alpha=div.find('a')
      while(alpha.findNext('a')):
        s=str(alpha['href'])
        if s.find("https://www.balancenutrition.in/recipes/")==-1:
          break
        alpha=alpha.findNext('a')
        l.append(alpha['href'])
        
    except:
      print()

energy=None
protein=None
carbo=None
fat=None
meter=None


for j in l:
 
  result = requests.get(j)
  src = result.content
  soup = BeautifulSoup(src, 'html.parser')
  try:
    f=len("https://www.balancenutrition.in/recipes/recipe-details/")
    fitem=j[f:]
    print(fitem)
    t1=soup.find('div',class_="recipe-heading")
    t2=t1.find('div')
    t3=str(t2.find('img'))
    k=(t3.find("https://www.balancenutrition.in/images/recipes/"))+len("https://www.balancenutrition.in/images/recipes/")
    p=t3.find(".png")
    typ=(t3[k:p])
    tag1=soup.find('div',class_="col-md-3 energy col-sm-6 col-xs-6 recipe-shared-btm")
    if(tag1!=None):
      energy=tag1.find('p')
 
    if(energy!=None):
      energy=energy.text
  
    tag2=soup.find('div',class_="col-md-3 protien col-sm-6 col-xs-6 recipe-shared-btm")
    if(tag2!=None):
      protein=tag2.find('p')
    if(protein!=None):
      protein=protein.text
    tag3=soup.find('div',class_="col-md-3 carbs col-sm-6 col-xs-6 recipe-shared-btm")
    if(tag3!=None):
      carbo=tag3.find('p')
    if(carbo!=None):
      carbo=carbo.text
    tag4=soup.find('div',class_="col-md-3 fats col-sm-6 col-xs-6 recipe-shared-btm")
    if(tag4!=None):
      fat=tag4.find('p')
    if(fat!=None):
      fat=fat.text
    tag5=soup.find('div',class_="health-meter")

    meter=tag5.find('p').text

    tag6=soup.find('div',class_='ingredient-list')
    if(tag6!=None):
      itemp1=tag6.find('ul')
    if(itemp1!=None):
      ind=itemp1.find_all('li')
    print(ind)
    indgredients=[]
  except:
     print()
  for i in ind:
    value=i.find('span',{"style":"line-height: 1.42857;"})
    if(value!=None):
      value=value.text
      indgredients.append(value)
  if(len(indgredients)==0):
    for k in ind:
      indgredients.append(k.text)
    
  li=[]
  li.append(fitem)
  li.append(typ)
  li.append(j)
  li.append(energy)
  li.append(protein)
  li.append(carbo)
  li.append(fat)
  li.append(meter)
  
  li.append(indgredients)
  print(li)
  with open(filename,'a',newline='') as csvfile:
        writer=csv.writer(csvfile,delimiter=',', dialect='excel')
        writer.writerow(li)
# Out:
# baked-modaks
# [<li>Freshly grated coconut - 2 tbsp<br/></li>, <li>Jaggery (gud) - <span style="color: rgb(77, 81, 86); font-family: arial, sans-serif; font-size: 14px;">½</span> tbsp<br/></li>, <li>Poppy seeds (roasted and coarsely crushed) - 1 tsp<br/></li>, <li>Cardamom powder - <span style="color: rgb(77, 81, 86); font-family: arial, sans-serif; font-size: 14px;">½</span> tsp<br/></li>, <li>Nutmeg powder - ¼ tsp</li>]
# ...

# %%
import requests
import csv
from bs4 import BeautifulSoup


filename="west_food.csv"
col=['Food Item','Type','Link','Energy','Protein','Carbohydrate','Fat','Health Meter','Indgredients'] 

#Refer to this for food 
l=[]
page = requests.get("https://www.balancenutrition.in/recipes/cuisines/rajasthani")
soup = BeautifulSoup(page.content, 'html.parser')
for div in soup.findAll('div', attrs={'class':'row cuisine'}):
    try:

      alpha=div.find('a')
      while(alpha.findNext('a')):
        s=str(alpha['href'])
        if s.find("https://www.balancenutrition.in/recipes/")==-1:
          break
        alpha=alpha.findNext('a')
        l.append(alpha['href'])
        
    except:
      print()

energy=None
protein=None
carbo=None
fat=None
meter=None


for j in l:
 
  result = requests.get(j)
  src = result.content
  soup = BeautifulSoup(src, 'html.parser')
  try:
    f=len("https://www.balancenutrition.in/recipes/recipe-details/")
    fitem=j[f:]
    print(fitem)
    t1=soup.find('div',class_="recipe-heading")
    t2=t1.find('div')
    t3=str(t2.find('img'))
    k=(t3.find("https://www.balancenutrition.in/images/recipes/"))+len("https://www.balancenutrition.in/images/recipes/")
    p=t3.find(".png")
    typ=(t3[k:p])
    tag1=soup.find('div',class_="col-md-3 energy col-sm-6 col-xs-6 recipe-shared-btm")
    if(tag1!=None):
      energy=tag1.find('p')
 
    if(energy!=None):
      energy=energy.text
  
    tag2=soup.find('div',class_="col-md-3 protien col-sm-6 col-xs-6 recipe-shared-btm")
    if(tag2!=None):
      protein=tag2.find('p')
    if(protein!=None):
      protein=protein.text
    tag3=soup.find('div',class_="col-md-3 carbs col-sm-6 col-xs-6 recipe-shared-btm")
    if(tag3!=None):
      carbo=tag3.find('p')
    if(carbo!=None):
      carbo=carbo.text
    tag4=soup.find('div',class_="col-md-3 fats col-sm-6 col-xs-6 recipe-shared-btm")
    if(tag4!=None):
      fat=tag4.find('p')
    if(fat!=None):
      fat=fat.text
    tag5=soup.find('div',class_="health-meter")

    meter=tag5.find('p').text

    tag6=soup.find('div',class_='ingredient-list')
    if(tag6!=None):
      itemp1=tag6.find('ul')
    if(itemp1!=None):
      ind=itemp1.find_all('li')
    print(ind)
    indgredients=[]
  except:
     print()
  for i in ind:
    value=i.find('span',{"style":"line-height: 1.42857;"})
    if(value!=None):
      value=value.text
      indgredients.append(value)
  if(len(indgredients)==0):
    for k in ind:
      indgredients.append(k.text)
    
  li=[]
  li.append(fitem)
  li.append(typ)
  li.append(j)
  li.append(energy)
  li.append(protein)
  li.append(carbo)
  li.append(fat)
  li.append(meter)
  
  li.append(indgredients)
  print(li)
  with open(filename,'a',newline='') as csvfile:
        writer=csv.writer(csvfile,delimiter=',', dialect='excel')
        writer.writerow(li)
# Out:
# bejar-roti
# [<li><span style="line-height: 1.42857;">Whole wheat flour-  1/2 tbsp</span><br/></li>, <li><span style="line-height: 1.42857;">Jowar (white millet) flour-  1/2 tbsp</span><br/></li>, <li><span style="line-height: 1.42857;">Besan (Bengal gram flour) -1/2 tbsp</span><br/></li>, <li><span style="line-height: 1.42857;">Roasted cumin seeds (jeera)-  ¼ tsp</span><br/></li>, <li><span style="line-height: 1.42857;">Green chilli paste -¼tsp</span><br/></li>, <li><span style="line-height: 1.42857;">Finely chopped coriander (dhania) -1 tsp</span><br/></li>, <li><span style="line-height: 1.42857;">Salt  Use minimum, to taste</span><br/></li>, <li><span style="line-height: 1.42857;">Oil-  ½ tsp</span><br/></li>]
# ...
